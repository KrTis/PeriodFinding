# %%
# %load_ext autoreload
# %autoreload 2
from imports import *
from simcodes.helpers import *
# %run simcodes/MultiBandSim.py
import os

import tqdm.notebook
import pandas as pd
import matplotlib.pyplot as plt

# %%
Gaia = pd.read_csv('data/gaia_periodic_sources.csv')
Gaia[['ra','dec','source_id']].to_csv('Gaia_short.csv')

# %%
Gaia = pd.read_csv('data/gaia_periodic_sources.csv')

# %%
Gaia.dropna(subset=['in ZTF'])['in ZTF'].hist()
plt.yscale('log')

# %%
(Gaia['in ZTF']>0).sum()
# Out:
# 401

# %%
plist = ['Period 1', 'Period 2', 'Period 3']
p0 = 'Period'
truths = [Gaia[p].isna() for p in plist]
#Gaia.loc[Gaia[p0].isna()& (~truths[0].isna())]
(Gaia[p0].isna()& (~truths[0].isna())).sum(),(Gaia[p0].isna()& truths[0].isna() & (~truths[1].isna())).sum(),(Gaia[p0].isna()& truths[0].isna() & (truths[1].isna())& (~truths[2].isna())).sum()
# Out:
# (187873, 0, 0)

# %%
plist = ['Period','Period 1', 'Period 2', 'Period 3']
N = Gaia.shape[0]
for i, p1 in enumerate(plist):
    stat  = (~Gaia[p1].isna() ).sum()
    k =  ['','',  "", p1, stat,100*stat/N]
    if stat>0:
                print( " %-12s %-12s %-12s %-12s %8d %7.3f"%tuple(k),'%' )
for i, p1 in enumerate(plist[:1]):
    for j, p2 in enumerate(plist[i+1:]):
        stat = (Gaia[p1].isna() & (~Gaia[p2].isna())).sum()
        k =  ['','',  'no '+p1, p2, stat,100*stat/N]
        if stat>0:
                print( " %-12s %-12s %-12s %-12s %8d %7.3f"%tuple(k),'%' )
    j = i+1
    p2 = plist[i+1]
    for k, p3 in enumerate(plist[i+j+1:]):
            stat =  (Gaia[p1].isna() & Gaia[p2].isna() & (~Gaia[p3].isna())).sum()
            k =  ['','no '+p1, 'no '+p2, p3,stat,100*stat/N]
            if stat>-1:
                print( " %-12s %-12s %-12s %-12s %8d %7.3f"%tuple(k),'%' )
    for j, p2 in enumerate(plist[i+1:-1]):
        for k, p3 in enumerate(plist[i+j+2:]):
            stat =  (Gaia[p1].isna() & (~Gaia[p2].isna()) & (~Gaia[p3].isna())).sum()
            k =  ['','no '+p1, p2, p3,stat,100*stat/N]
            if stat>-1:
                print( " %-12s %-12s %-12s %-12s %8d %7.3f"%tuple(k),'%' )
stat = (Gaia[plist[0]].isna() & Gaia[plist[1]].isna() & (Gaia[plist[2]].isna())& (~Gaia[plist[3]].isna())).sum()
k = ['no '+p for p in plist[:-1]]+plist[-1:]+[stat,100*stat/N]
print( " %-12s %-12s %-12s %-12s %8d %7.3f"%tuple(k),'%' )
stat = (Gaia[plist[0]].isna() & Gaia[plist[1]].isna() & (Gaia[plist[2]].isna())& (Gaia[plist[3]].isna())).sum()
k = ['no '+p for p in plist]+[stat,100*stat/N]
print( " %-12s %-12s %-12s %-12s %8d %7.3f"%tuple(k),'%' )
stat = (~(Gaia[plist[0]].isna() & Gaia[plist[1]].isna() & (Gaia[plist[2]].isna())& (Gaia[plist[3]].isna()))).sum()
k = plist+[stat,100*stat/N]
print( " %-12s %-12s %-12s %-12s %8d %7.3f"%tuple(k),'%' )
# Out:
#                                         Period         176096  48.382 %
#                                         Period 1        29379   8.072 %
#                                         Period 2          138   0.038 %
#                                         Period 3            5   0.001 %
#                            no Period    Period 1        27580   7.578 %
#                            no Period    Period 2           68   0.019 %
#                            no Period    Period 3            5   0.001 %
#               no Period    no Period 1  Period 2            0   0.000 %
#               no Period    no Period 1  Period 3            0   0.000 %
#               no Period    Period 1     Period 2           68   0.019 %
#               no Period    Period 1     Period 3            5   0.001 %
#               no Period    Period 2     Period 3            0   0.000 %
#  no Period    no Period 1  no Period 2  Period 3            0   0.000 %
# ...

# %%
cluster = SSHCluster(["dodo1","dodo1",'dodo2','dodo3','dodo4']+["dodo5","dodo6"],
    worker_options={"nthreads": 100},
                connect_options={"known_hosts": None,"username": "ktisanic"},
                scheduler_options={"port": 0, "dashboard_address": ":46065"}
            )
cluster
# Out:
# distributed.deploy.ssh - INFO - distributed.scheduler - INFO - -----------------------------------------------
# distributed.deploy.ssh - INFO - /home/ktisanic/anaconda3/lib/python3.8/site-packages/distributed/node.py:151: UserWarning: Port 46065 is already in use.
# distributed.deploy.ssh - INFO - Perhaps you already have a cluster running?
# distributed.deploy.ssh - INFO - Hosting the HTTP server on port 44037 instead
# distributed.deploy.ssh - INFO - warnings.warn(
# distributed.deploy.ssh - INFO - distributed.scheduler - INFO - -----------------------------------------------
# distributed.deploy.ssh - INFO - distributed.scheduler - INFO - Clear task state
# distributed.deploy.ssh - INFO - distributed.scheduler - INFO -   Scheduler at: tcp://192.168.200.104:36091
# distributed.deploy.ssh - INFO - distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.200.104:38287'
# ...

# %%
g1 = Gaia[Gaia['in ZTF']>0]
g1.loc[g1.loc[:,'best_class_name'].str.contains('CEP'),'Type'] = 'CEP'
g1.loc[g1.loc[:,'best_class_name'].str.contains('RR'),'Type'] = 'RR'
g1.loc[:,'Subtype'] = g1.loc[:,'best_class_name']

def ZTFAnalysis(starsfull,cluster):
    types = ['CEP','RR']
    Analysis = pd.DataFrame()
    Nreps = 8#
    Percents =  [30,50]

    stats = ['mean','median','std','sem',p16,p84,med_sig,unexplained_variance,Outliers1,Outliers3]
    Stats = ['mean','median','std','sem','p16','p84','med_sig','unexplained_variance', 'Outliers1','Outliers3']
    Widths = np.round(np.logspace(-3,np.log10(0.4),10),3)
    for _type in types:
        stars1 = starsfull[starsfull['Type']==_type].reset_index()
        subs = pd.unique(stars1['Subtype'])
        for _sub in subs:
            stars = stars1[stars1['Subtype']==_sub].reset_index()
            for w in Widths:
                    try:
                        os.mkdir(f'outputs/windows/w_{w}/')
                    except:
                        pass
            for i,row in stars.head(100).iterrows():
                for w in Widths:
                    with open('Bootstrap_log_ZTF.txt','w') as log:
                            print(i, row['source_id'],end='\t',file=log)
                            print(i, row['source_id'],end='\t')
                            filename = f"data/ZTF/{row['source_id']}.csv"
                            D =  pd.read_csv(filename)

                            D['t'] = D['mjd']
                            D['filt'] = D['filtercode']
                            D.to_csv(filename)
                            #for V, d in D.groupby(D['filt']):
                            #    plt.scatter(d['phase'],d['mag'])
                            #plt.show()
                            inds = pd.unique(D['filtercode'])
                            Nmax = D.index.size
                            Sim = MCSimulation("data/ZTF/", row['pf'], filename,verbose=False,memory_type='index')
                            Sim.compute_phase()

                            #for Per in Percents:
                            ok = False


                            for _ in range(1):
                                    Sim.produce_bootstrap(Percents,Nreps)
                                    Sim.remove_window_variable_width(np.array([Widths.size*[0.5],Widths]).T)
                                    print(f"Bootstrap {_}",end='\t',file=log)
                                    print(f"Bootstrap {_}", end='\t')
                                    #Sim.produce_bootstrap([Per],Nreps)
                                    try:
                                        Sim.run_simulation('fast',cluster=cluster)
                                        Sim.Simulated_periods.loc[:,'w'] = np.tile(Widths, np.sort(np.tile(Percents,Nreps)).size)
                                        ok = True
                                    except:
                                        print(Percents,'Fail',end='\t')
                                        print(Percents,'Fail',end='\t',file=log)
                                    if ok:
                                        for w in Widths:

                                                _Sim = Sim.Simulated_periods.loc[Sim.Simulated_periods['w']==w,:]
                                                _Sim.loc[:,'N'] = _Sim['N'].astype(float)/len(inds)
                                                _Sim.loc[:,'Nbin'] = pd.cut(_Sim['N'],[10,20,30,50,np.inf])
                                                Stat = _Sim.groupby('Nbin').agg({'P':stats,'N':'mean'})

                                                for ind in Stat.index:
                                                    Dict = {'Name':row['source_id'],'Gaia period':row['pf'],#'LS period':Sim.best_fitting[1],
                                                    }
                                                    for st in Stats:
                                                        Dict[st] = Stat.loc[ind,('P',st)]
                                                    Dict['window'] = w
                                                    Dict['Nobs'] = ind
                                                    Dict['mean N'] = Stat.loc[ind,('N','mean')]
                                                    Dict['Type'] = _type
                                                    Dict['Subtype'] = _sub
                                                    Analysis = Analysis.append(Dict, ignore_index=True)
                                                    Analysis.to_csv('ManystarsZTF.csv')
                                        print(ok)
                                        print(ok,file=log)

                                        break
    return Analysis
Analysis = ZTFAnalysis(g1,cluster)

# %%
g1.loc[g1.loc[:,'best_class_name'].str.contains('CEP'),'Type'] = 'CEP'
g1.loc[g1.loc[:,'best_class_name'].str.contains('RR'),'Type'] = 'RR'
g1.loc[:,'Subtype'] = g1.loc[:,'best_class_name']
g1

# %%
Analysis = pd.read_csv('ManystarsZTF.csv')
Analysis['IQR Z score'] = (Analysis[f'median']-Analysis['Gaia period'])/Analysis['med_sig']
Analysis['IQR Q']       = Analysis['IQR Z score']**2
Analysis['log IQR Q'] = np.log10(Analysis['IQR Q'])
Analysis['IQR ratio'] = Analysis['med_sig']/Analysis['median']
Analysis['dP/P']      = abs(Analysis[f'median']-Analysis['Gaia period'])/Analysis['Gaia period']
Analysis['log dP/P']   = np.log10(Analysis['dP/P'] )
Analysis['unexplained variance ratio'] = np.sqrt(Analysis[f'unexplained_variance']/Analysis[f'median']**2)
Analysis['log IQR ratio'] =np.log10(Analysis['IQR ratio'] )

Analysis['log unexplained variance ratio'] =np.log10(Analysis['unexplained variance ratio'] )
def FeaturePlot(Analysis:pd.DataFrame, folder, idx):
            if Analysis.index.size>0:
               

                Nobs = pd.unique(Analysis.Nobs)[:-1]
                Wobs = pd.unique(Analysis.window)
                colors = plt.cm.jet(np.linspace(0,1,len(Wobs)))
                fig, ax = plt.subplots(ncols=Nobs.size, nrows=5, constrained_layout=True,figsize=(4*Nobs.size,4*4),
                                             gridspec_kw=dict(width_ratios=Nobs.size*[1], height_ratios=[1,1,1,1,1]),dpi=150)
                ax = ax.reshape(5,Nobs.size)
                for a,[_n,g] in zip(ax[0],Analysis.groupby('Nobs')):
                    bins = np.logspace(-5,2,50)
                    for color,[_w,K] in zip(colors,g.groupby('window')):

                        a.hist((K['IQR Q']),bins,label=f'w={_w}',histtype='step',color=color,density=True)
                    a.plot(bins,sc.chi2(1).pdf(bins),'k',label=r'$\chi^2(1)$')

                        #a.axvline((K['IQR Z score']).median(),color=color,ls='dashed')
                    a.set_yscale('log')
                    a.set_xscale('log')
                    a.set_title(f'N={_n}')
                    a.legend()
                    a.set_xlabel(r'$\left(\frac{P-P_{OGLE}}{\sigma_{IQR}}\right)^2$')
                for a,[_n,g] in zip(ax[1],Analysis.groupby('Nobs')):
                    for color,[_w,K] in zip(colors,g.groupby('window')):
                        a.hist((K['IQR ratio']),np.logspace(-10,2,20),label=f'w={_w}',histtype='step',color=color,density=True)
                    a.set_yscale('log')
                    a.set_xscale('log')
                    a.set_title(f'N={_n}')
                    a.legend()
                    a.set_xlabel(r'$\frac{\sigma_{IQR}}{P}$')
                for a,[_n,g] in zip(ax[2],Analysis.groupby('Nobs')):
                    for color,[_w,K] in zip(colors,g.groupby('window')):
                        a.hist((K['unexplained variance ratio']),np.logspace(-10,2,20),label=f'w={_w}',histtype='step',color=color,density=True)
                    a.set_yscale('log')
                    a.set_xscale('log')
                    a.set_title(f'N={_n}')
                    a.legend()
                    a.set_xlabel(r'$\frac{\sqrt{\sigma^2-\sigma_{IQR}^2}}{P}$')
                for a,[_n,g] in zip(ax[3],Analysis.groupby('Nobs')):
                    for color,[_w,Ks] in zip(colors,g.groupby('window')):
                        Ks = Ks.dropna()
                        K = Ks[Ks['IQR Q']<1][['IQR ratio','dP/P']].dropna()
                        if K.index.size>1:
                            counts,ybins,xbins = np.histogram2d(K['IQR ratio'], K['dP/P'],bins=np.logspace(-10,3,20))
                            a.contour(*np.meshgrid(0.5*(xbins[:-1]+xbins[1:]), 0.5*(ybins[:-1]+ybins[1:]),indexing='ij'),counts/np.sum(counts),levels=np.logspace(-2,0,2),colors=5*[color])
                        K = Ks[Ks['IQR Q']>20][['IQR ratio','dP/P']].dropna()
                        if K.index.size>1:
                            counts,ybins,xbins = np.histogram2d(K['IQR ratio'], K['dP/P'],bins=np.logspace(-10,3,20))
                            a.contour(*np.meshgrid(0.5*(xbins[:-1]+xbins[1:]), 0.5*(ybins[:-1]+ybins[1:]),indexing='ij'),counts/np.sum(counts),levels=np.logspace(-2,0,2),colors=5*[color],linestyles='dashed')
                        a.set_yscale('log')
                        a.set_xscale('log')
                        a.set_xlabel(r'$\frac{\sigma_{IQR}}{P}$')
                        a.set_ylabel(r'$\left|\frac{P-P_{OGLE}}{P}\right|$')
                for a,[_n,g] in zip(ax[4],Analysis.groupby('Nobs')):
                    for color,[_w,Ks] in zip(colors,g.groupby('window')):
                        Ks = Ks.dropna()
                        K = Ks[Ks['IQR Q']<1][['unexplained variance ratio','dP/P']].dropna()
                        if K.index.size>1:
                            counts,ybins,xbins = np.histogram2d(K['unexplained variance ratio'], K['dP/P'],bins=np.logspace(-10,3,20))
                            a.contourf(*np.meshgrid(0.5*(xbins[:-1]+xbins[1:]), 0.5*(ybins[:-1]+ybins[1:]),indexing='ij'),counts/np.sum(counts),levels=np.logspace(-2,0,10),colors=5*[color])
                            a.plot(K['unexplained variance ratio'], K['dP/P'],'.')
                        K = Ks[Ks['IQR Q']>20][['unexplained variance ratio','dP/P']].dropna()
                        if K.index.size>1:
                            counts,ybins,xbins = np.histogram2d(K['unexplained variance ratio'], K['dP/P'],bins=np.logspace(-10,3,20))
                            a.contour(*np.meshgrid(0.5*(xbins[:-1]+xbins[1:]), 0.5*(ybins[:-1]+ybins[1:]),indexing='ij'),counts/np.sum(counts),levels=np.logspace(-2,0,10),colors=5*[color],linestyles='dashed')
                            a.plot(K['unexplained variance ratio'], K['dP/P'],'.')
                        a.set_yscale('log')
                        a.set_xscale('log')
                        a.set_xlabel(r'$\frac{\sqrt{\sigma^2-\sigma_{IQR}^2}}{P}$')
                        a.set_ylabel(r'$\left|\frac{P-P_{OGLE}}{P_{OGLE}}\right|$')
                fig.savefig(folder+f'Sim_{idx}.pdf')
                from corner import corner

                K = Analysis[Analysis['IQR Q']<0.1].replace([np.inf, -np.inf], np.nan).dropna()
                if K.index.size>3:
                    fig=corner(K[['log IQR ratio','log unexplained variance ratio','log dP/P']]);
                    K = Analysis[Analysis['IQR Q']>10].replace([np.inf, -np.inf], np.nan).dropna()
                    if K.index.size>3:
                        corner(K[['log IQR ratio','log unexplained variance ratio','log dP/P']],fig=fig,color='r',
                           labels=[r'$\log\frac{\sigma_{IQR}}{P}$',r'$\log\frac{\sqrt{\sigma^2-\sigma_{IQR}^2}}{P}$',r'$\log\left|\frac{P-P_{OGLE}}{P_{OGLE}}\right|$']).savefig(folder+f'Sim_{idx}_corner.pdf' ,dpi=100);
                        
FeaturePlot(Analysis, 'plots/Gaia/', f'CEP_T2CEP')
# Out:
# /home/ktisanic/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/ktisanic/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/ktisanic/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/ktisanic/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# /home/ktisanic/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# ...

# %%
import simcodes.ExtendedPeriodic
import tqdm
import itertools
Gaia = pd.read_csv('data/gaia_periodic_sources.csv')
g1 = Gaia[Gaia['in ZTF']>0]
g1.loc[g1.loc[:,'best_class_name'].str.contains('CEP'),'Type'] = 'CEP'
g1.loc[g1.loc[:,'best_class_name'].str.contains('RR'),'Type'] = 'RR'
g1.loc[:,'Subtype'] = g1.loc[:,'best_class_name']
# Out:
# /home/ktisanic/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ktisanic/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
import gatspy
import folders
g2=g1[g1.Type.isin(['CEP','RR'])].reset_index(drop=True)
lib = simcodes.ExtendedPeriodic.LibraryCreation(g2,'LibraryCEPRRLyr.csv','data/ZTF/',[1])
for i0,[data, datum,D,predictions,periodogram,best] in tqdm.tqdm(enumerate(lib),total=g2.shape[0]):
    fig,ax = plt.subplots(3,2,figsize=(15,10))
    ax = ax.flatten()
    for i,[_filter,_lightcurve] in enumerate(D.groupby(D.filt)): 
        for a, phase in zip(ax,['phase','fit phase','fit phase 1', 'fit phase 2']):
            a.errorbar(_lightcurve[phase],_lightcurve['mag'],fmt='.',color=f'C{i}',yerr=_lightcurve['magerr'],label=_filter)
        #ax[4].scatter(_lightcurve['prediction']-_lightcurve['mag'],_lightcurve['prediction 1']-_lightcurve['mag'],
        #              label=_filter,color=f'C{i}')
        
    for i,[_filter,_lightcurve] in enumerate(predictions.groupby(predictions.filt)): 
        for a, fit in zip(ax,['mag Gaia','mag fit','mag fit 1', 'mag fit 2']):
            a.plot(_lightcurve['phase'],_lightcurve[fit],color=f'C{i}',)
            a.invert_yaxis()
        
    ax[4].plot([i for i in range(best[0].size)],[datum[f'χ2 {i}/dof'] for i in range(best[0].size)])    
    ax[5].plot(*periodogram)
    ax[5].axvline(datum['Expected'],color='r',label='Gaia',lw=1)
    ax[5].axvline(datum['_best_period'],color='b',label='Fit',lw=1)
    for _i,_p in enumerate(best[0][1:4]):
        ax[5].axvline(datum[f'LS period {_i}'],color=f'C{_i}',label=f'Fit {_i}',lw=1)
    for a in ax[:4]:
        a.legend()
    ax[5].set_xscale('log')
    ax[4].set_yscale('log')
    ax[4].set_xlabel('n-th best fit')
    ax[4].set_ylabel(r'$\chi^2/(N-1)$')
   
    ax[5].set_xlabel('Period')

    ax[0].set_title('Gaia period %.4f'%datum['Expected'])
    ax[1].set_title('LS period %.4f'%datum['_best_period'])
    ax[2].set_title('LS period from 2nd best fit %.4f'%datum['LS period 1'])
    ax[3].set_title('LS period from 3rd best fit %.4f'%datum['LS period 2'])
    fig.savefig(folders.plot_folder+f"ztf/{datum['Subtype']}_{datum['source_id']}_Nterms_{datum['Nterms']}.png" ,bbox_extra_artists=[fig.suptitle(f"ID={datum['source_id']} {datum['Subtype']}")], bbox_inches='tight')
    #fig.savefig(folders.plot_folder+f"ztf/{datum['Subtype']}_{datum['source_id']}_Nterms_{datum['Nterms']}.png" ,bbox_extra_artists=[fig.suptitle(f"ID={datum['source_id']} {datum['Subtype']}")], bbox_inches='tight')
    plt.close(fig)
# Out:
#  30%|██▉       | 120/401 [1:16:45<2:59:43, 38.38s/it]

# %%
# Out:
# Point(r=1, ϕ=1)

# %%
plt.hist(D.magerr)
# Out:
# (array([17.,  7., 11., 15., 12., 20.,  9., 18., 25.,  9.]),
#  array([0.01185852, 0.01192848, 0.01199843, 0.01206839, 0.01213834,
#         0.0122083 , 0.01227826, 0.01234821, 0.01241817, 0.01248812,
#         0.01255808]),
#  <a list of 10 Patch objects>)

# %%
import matplotlib

with matplotlib.rc_context({"font.size" : 20,'axes.labelsize':20}) as k:
    fig,ax = plt.subplots(1,1,figsize=(5,5))
    im=ax.scatter(np.abs(data['χ2 0/dof']),np.abs(data['χ2 1/dof']),c=np.log10(data['χ2']))
    fig.colorbar(im)
    ax.set_xlabel(r"$\chi^2_{dof}$ best fit")
    ax.set_ylabel(r"$\chi^2_{dof}$ 2nd best fit")
    ax.set_xscale('log')
    ax.set_yscale('log')

# %%
# %run simcodes/ExtendedPeriodic.py
import scipy.stats
concatenated,lognorm_fit,lognorm = simcodes.ExtendedPeriodic.concatenating(g2,'data/ZTF/',scipy.stats.lognorm)
concatenated.info()
lognorm_fit
data =data.reset_index(drop=True)
data.to_csv(folders.data_folder+'ZTF/simulations/library.csv')
#simulations = simcodes.ExtendedPeriodic.produce_samples(data, np.tile(np.arange(5,100),100),lognorm)
simulations = produce_samples_dask(Client("tcp://192.168.200.104:36091"),data,np.tile(np.arange(5,70),10),lognorm)
print('produced')
simulations['key'] = 0
carts = pd.DataFrame({"Nterms used":[1,2,3]})
carts['key'] = 0
simulations=simulations.set_index('key').join(carts.set_index('key')).reset_index(drop=True)
def PeriodLimits(df):
    bp = df['_best_period'].iloc[0]
    return pd.Series({"period min":max(np.diff(df.t).min(),0.1*bp), "period max":min(10*bp,df.t.max())})
simulations = simulations.set_index(["simulation index",'Nterms used'])\
                         .join(simulations.groupby(["simulation index",'Nterms used'])\
                         .apply( PeriodLimits)).drop(columns=['_best_period']).reset_index()
print('limits applied')
simulations.to_csv(folders.data_folder+'ZTF/simulations/simulations.csv')

with matplotlib.rc_context({"font.size" : 15,'axes.labelsize':15}) as k:
    fig,ax = plt.subplots(1,2,figsize=(10,5))
    
    ax[0].hist(concatenated.magerr,100,density=True,label='dataset',histtype='step')
    ax[0].hist(simulations.magerr,100,density=True,label='simulated',histtype='step')
    ax[0].legend()
    ax[0].set_xlabel('magnitude error');
    ax[1].plot(np.logspace(-4,-2,1000),lognorm.pdf(np.logspace(-4,-2,1000)),'k-',)
    ax[1].set_xscale('log')
    ax[1].set_xlabel('Relative error')
    ax[1].hist(concatenated['magerr']/concatenated.mag,np.logspace(-4,-2,100),density=True,label='dataset',histtype='step')
    ax[1].hist(simulations['magerr']/simulations.mag,np.logspace(-4,-2,100),density=True,label='simulated',histtype='step')
    ax[1].legend()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49712 entries, 0 to 171
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   t               49712 non-null  float64
#  1   phase           49712 non-null  float64
#  2   mag             49712 non-null  float64
#  3   filt            49712 non-null  object
#  4   magerr          49712 non-null  float64
#  5   row             49712 non-null  int64
#  6   relative_error  49712 non-null  float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 3.0+ MB

# %%
def MapWrapper(index,Df):
        df = Df.loc[index].reset_index()
        pars = df.iloc[0]
        model =  gatspy.periodic.LombScargleMultiband(fit_period=True,optimizer_kwds=dict(quiet=True),Nterms_base=pars['Nterms used'])
        model.optimizer.period_range=(pars['period min'],pars['period max'])
        try:
            return index[0],index[1],model.fit(df.t,df.mag,df.magerr,df.filt)._best_period
        except:
            return index[0],index[1],np.nan
sim = simulations.set_index(['simulation index','Nterms used'])
ind = pd.unique(sim.index)

# %%
# %timeit sim.loc[ind[:600]]
# %timeit sim.loc[:ind[600]]
# Out:
# 2.16 s ± 49.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 32.6 ms ± 199 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
sim.loc[:ind[600]]
# Out:
#                                        t        mag    magerr filt  \
# simulation index Nterms used
# 0                1            526.751552  15.629625  0.013116   zg
#                  1            887.935337  14.595992  0.014549   zg
#                  1              0.000000  14.376995  0.024161   zg
#                  1            501.119799  15.265314  0.013374   zg
#                  1            686.545085  14.029741  0.017766   zg
# ...                                  ...        ...       ...  ...
# 200              1            681.967830  12.752441  0.009940   zr
#                  1            786.052761  12.948000  0.012768   zr
#                  1            246.570943  12.670753  0.010362   zr
#                  1            579.219404  12.647991  0.008438   zr
#                  1            788.102230  12.862909  0.015688   zr
#
#                               data index  Size  period min  period max
# simulation index Nterms used
# ...

# %%
for i in range()
# Out:
# array([(0, 1), (0, 2), (0, 3), ..., (77999, 1), (77999, 2), (77999, 3)],
#       dtype=object)

# %%
with Client("tcp://192.168.200.104:36091") as client:
    L0 = []
    l = np.arange(0,np.size(ind)+1,600)
    for cut in tqdm.tqdm(range(1,len(l))):
        L0 =L0+ client.gather(client.map(MapWrapper,ind[l[cut-1]:l[cut]],Df=sim.loc[ind[l[cut-1]]:ind[l[cut]-1]]))
# Out:
# 100%|██████████| 390/390 [5:16:25<00:00, 48.68s/it]

# %%
L = pd.DataFrame(L0,columns=['simulation index','Nterms used','simulated period'])\
      .set_index(['simulation index','Nterms used'])
simulations.drop_duplicates(subset=['simulation index','Nterms used'])\
           .set_index(['simulation index','Nterms used'])\
           .join(L).reset_index().set_index('data index')\
           .join(data).reset_index(drop='True')\
           .to_csv(folders.data_folder+'ZTF/simulations/simulations_summary_output.csv')

# %%
simulations.set_index(['simulation index','Nterms used'])\
           .join(L).reset_index().set_index('data index')\
           .join(data).reset_index(drop='True')\
           .to_csv(folders.data_folder+'ZTF/simulations/simulations_full_output.csv')

# %%
print('a')
# Out:
# a

# %%
d       = pd.read_csv(folders.data_folder+'ZTF/simulations/simulations_summary_output.csv',index_col=0)
d['dP'] = d['simulated period']-d['_best_period']
d['|dP|'] =np.abs( d['simulated period']-d['_best_period'])
d['dP/P'] = d['dP']/d['_best_period']
d['log dP/P'] = np.log10(np.abs(d['dP/P']))
#plt.plot(d.Size,d.dP,'.')
with matplotlib.rc_context({"font.size" : 20,'axes.labelsize':20}):
    fig, ax = plt.subplots(2,2,figsize=(13,10))
    ax=ax.flatten()
    for _, _d in d.dropna().groupby(d.dropna()['Nterms used']):
        if _<3:
            func = [lambda x: np.percentile(x,16),
                           lambda x: np.percentile(x,50),
                           lambda x: np.percentile(x,84),
                          lambda x: scipy.stats.sem(x)]
            vals = {'dP/P':func }

            i = _d.groupby(_d.Size).agg(vals)                                                                               
            i.columns = ['p_16', 'p_50', 'p_84','sem']

            ax[0].plot(i.index,i['p_50'],label=f'{_} LS terms')
            ax[0].set_ylim(-1,1)
            #ax[0].set_yscale('log')
            vals = {'log dP/P':func }
            i = _d.groupby(d.Size).agg(vals)                                                                               
            i.columns = ['p_16', 'p_50', 'p_84','sem']
            ax[1].set_yscale('log')
            ax[1].plot(i.index,10**i['p_50'],label=f'{_} LS terms')
            ax[1].fill_between(i.index,10**i['p_16'],10**i['p_84'],alpha=0.5)
            _d.drop_duplicates(subset=['source_id'])['Subtype'].hist(ax=ax[3])
    dd1=d.groupby(['Nterms used','Size']).count().reset_index()
    dd1['frac'] = 100*dd1['simulated period']/dd1['Subtype']
    for _, _d in dd1.groupby(dd1['Nterms used']):
        ax[2].plot(_d.Size,_d['frac'],label=f'{_} LS terms')
    for a in ax[:3]:
        a.set_xlim(5,70)
        a.legend()
        a.set_xlabel('Simulated observations per band')
    ax[0].set_xlim(5,30)
    ax[0].set_ylabel(r'$\frac{P_{sim}-P_{ZTF}}{P_{ZTF}}$ ')
    ax[1].set_ylabel(r'$\left|\frac{P_{sim}-P_{ZTF}}{P_{ZTF}}\right|$ ')
    ax[2].set_ylabel(r'% of successful fits')
    
    
    fig.tight_layout()
    fig.savefig(folders.plot_folder+f"ztf/simulations.png" , bbox_extra_artists=[fig.suptitle("Median simulated period",y=1.01)],bbox_inches='tight')
    
    for sub,d_ in d.groupby(d.Subtype):
        fig, ax = plt.subplots(1,2,figsize=(13,5))
        for _, _d in d_.dropna().groupby(d_.dropna()['Nterms used']):
            if _<3:
                func = [lambda x: np.percentile(x,16),
                               lambda x: np.percentile(x,50),
                               lambda x: np.percentile(x,84),
                              lambda x: scipy.stats.sem(x)]
                vals = {'dP/P':func }

                i = _d.groupby(_d.Size).agg(vals)                                                                               
                i.columns = ['p_16', 'p_50', 'p_84','sem']

                ax[0].plot(i.index,i['p_50'],label=f'{_} LS terms')
                ax[0].set_ylim(-1,1)
                #ax[0].set_yscale('log')
                vals = {'log dP/P':func }
                i = _d.groupby(_d.Size).agg(vals)                                                                               
                i.columns = ['p_16', 'p_50', 'p_84','sem']
                ax[1].set_yscale('log')
                ax[1].plot(i.index,10**i['p_50'],label=f'{_} LS terms')
                ax[1].fill_between(i.index,10**i['p_16'],10**i['p_84'],alpha=0.5)

        for a in ax:
            a.set_xlim(5,70)
            a.legend()
            a.set_xlabel('Simulated observations per band')
        ax[0].set_ylabel(r'$\frac{P_{sim}-P_{ZTF}}{P_{ZTF}}$ ')
        ax[1].set_ylabel(r'$\left|\frac{P_{sim}-P_{ZTF}}{P_{ZTF}}\right|$ ')
        ax[0].set_xlim(5,30)
        fig.tight_layout()
        fig.savefig(folders.plot_folder+f"ztf/simulations_{sub}.png" , bbox_extra_artists=[fig.suptitle(f"Median simulated period {sub}",y=1.01)],bbox_inches='tight')

# %%
import folders
Gaianew = pd.read_csv(folders.data_folder+'Gaia_temp.csv',index_col=0)
Gaianew.loc[Gaianew['Type']=='CEP',:].to_csv(folders.data_folder+'ZTF catalogs/DR3_CEP.csv')

# %%
Cepheids_dr3['Period any'].isna().sum()
# Out:
# 0

# %%
import folders
import simcodes.ExtendedPeriodic
import simcodes.formatters
Cepheids_dr3 = pd.read_csv(folders.ZTF_catalogs+'DR3_CEP.csv',index_col=0)
Components = [1,2,3]
TotalLen = Cepheids_dr3.shape[0]*len(Components)
lib          = simcodes.ExtendedPeriodic.LibraryCreation(Cepheids_dr3,
                                                         library_name=folders.ZTF_libraries+'CEP_dr3.csv',
                                                         folder=folders.ZTF_data+'3_arcsec/',
                                                         FourierComponents=Components)
for i0,[data, datum,D,predictions,periodogram,best] in tqdm.tqdm(enumerate(lib),total=TotalLen):
    fig,ax = plt.subplots(3,2,figsize=(15,10))
    ax = ax.flatten()
    for i,[_filter,_lightcurve] in enumerate(D.groupby(D.filt)): 
        for a, phase in zip(ax,['phase','fit phase','fit phase 1', 'fit phase 2']):
            a.errorbar(x=_lightcurve[phase],
                       y=_lightcurve['mag'],
                       fmt='.',color=f'C{i}',
                       yerr=_lightcurve['magerr'],
                       label=_filter)

        
    for i,[_filter,_lightcurve] in enumerate(predictions.groupby(predictions.filt)): 
        for a, fit in zip(ax,['mag Gaia','mag fit','mag fit 1', 'mag fit 2']):
            a.plot(_lightcurve['phase'],_lightcurve[fit],color=f'C{i}',)
    for a, fit in zip(ax,['mag Gaia','mag fit','mag fit 1', 'mag fit 2']):
        a.invert_yaxis()
        
    ax[4].plot([i for i in range(best[0].size)],[datum[f'χ2 {i}/dof'] for i in range(best[0].size)])    
    ax[5].plot(*periodogram)
    ax[5].axvline(datum['Expected'],color='r',label='Gaia',lw=1)
    ax[5].axvline(datum['_best_period'],color='b',label='Fit',lw=1)
    for _i,_p in enumerate(best[0][1:4]):
        ax[5].axvline(datum[f'LS period {_i}'],color=f'C{_i}',label=f'Fit {_i}',lw=1)
    for a in ax[:4]:
        a.legend()
    ax[5].set_xscale('log')
    ax[4].set_yscale('log')
    ax[4].set_xlabel('n-th best fit')
    ax[4].set_ylabel(r'$\chi^2/(N-1)$')
    ax[5].set_xlabel('Period')
    ax[0].set_title('Gaia period %.4f'%datum['Expected'])
    ax[1].set_title('LS period %.4f'%datum['_best_period'])
    ax[2].set_title('LS period from 2nd best fit %.4f'%datum['LS period 1'])
    ax[3].set_title('LS period from 3rd best fit %.4f'%datum['LS period 2'])
    fig.savefig(folders.ZTF_lightcurves\
                +simcodes.formatters.plot_name(datum['Subtype'],ID=datum['source_id'],Nterms=datum['Nterms']),
                bbox_extra_artists=[fig.suptitle(f"ID={datum['source_id']} {datum['Subtype']}")], 
                bbox_inches='tight')
    plt.close(fig)
# Out:
#   1%|          | 9/822 [27:23<35:35:50, 157.63s/it]

# %%
data.groupby('Nterms').mean().plot(y='χ2')

# %%
concatenated
# Out:
#                            t        mag filt    magerr  row  relative_error
# oid
# 280104400014568     0.000000  15.088459   zg  0.021127    0        0.001400
# 280104400014568    14.022037  15.792720   zg  0.022247    0        0.001409
# 280104400014568    28.957951  15.532755   zg  0.021714    0        0.001398
# 280104400014568    32.022187  15.792949   zg  0.022247    0        0.001409
# 280104400014568    34.915949  15.066093   zg  0.021106    0        0.001401
# ...                      ...        ...  ...       ...  ...             ...
# 1769116300050644  177.784398  12.629005   zg  0.010979    0        0.000869
# 1769116300050644  178.810949  13.043657   zg  0.010964    0        0.000841
# 1769116300050644  181.772188  13.260133   zg  0.010968    0        0.000827
# 1769116300050644  184.931875  13.302087   zg  0.010970    0        0.000825
# 1769116300050644  225.608947  13.374367   zg  0.010974    0        0.000821
#
# [421656 rows x 6 columns]

# %%
lognorm_fit,lognorm scipy.stats.lognorm

# %%
import scipy.stats
import simcodes.ExtendedPeriodic
concatenated = simcodes.ExtendedPeriodic.concatenating(data,folders.ZTF_data+'3_arcsec/',)
print(concatenated.info())
fits={}
for i, _d in concatenated.groupby('Nterms'):
    fit = scipy.stats.lognorm.fit(_d.relative_error)
    fits[i]={'fit':fit,'pdf':scipy.stats.lognorm(*fit)}
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421656 entries, 280104400014568 to 1769116300050644
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   t               421656 non-null  float64
#  1   mag             421656 non-null  float64
#  2   filt            421656 non-null  object
#  3   magerr          421656 non-null  float64
#  4   row             421656 non-null  int64
#  5   relative_error  421656 non-null  float64
#  6   Nterms          421656 non-null  int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 25.7+ MB
# None

# %%
import matplotlib
with matplotlib.rc_context({"font.size" : 15,'axes.labelsize':15}) as k:
    for i, _d in concatenated.groupby('Nterms'):
        fig,ax = plt.subplots(1,2,figsize=(10,5))

        ax[0].hist(_d.magerr,100,density=True,label='dataset',histtype='step')
        ax[0].hist(simulations[i].magerr,100,density=True,label='simulated',histtype='step')
        ax[0].legend()
        ax[0].set_xlabel('magnitude error');
        ax[1].plot(np.logspace(-4,-2,1000),fits[i]['pdf'].pdf(np.logspace(-4,-2,1000)),'k-',)
        ax[1].set_xscale('log')
        ax[1].set_xlabel('Relative error')
        ax[1].hist(_d['magerr']/_d.mag,np.logspace(-4,-2,100),density=True,label='dataset',histtype='step')
        ax[1].hist(simulations[i]['magerr']/simulations[i].mag,np.logspace(-4,-2,100),density=True,label='simulated',histtype='step')
        ax[0].set_title(i)
        ax[1].legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-35a02931b336> in <module>
#       5
#       6         ax[0].hist(_d.magerr,100,density=True,label='dataset',histtype='step')
# ----> 7         ax[0].hist(simulations[i].magerr,100,density=True,label='simulated',histtype='step')
#       8         ax[0].legend()
#       9         ax[0].set_xlabel('magnitude error');
#
# KeyError: 1

# %%
# %run simcodes/ExtendedPeriodic.py
simulations={}
for Nterms,_data in data.groupby('Nterms'):
    _data =_data.reset_index()
    simulations[Nterms] = produce_samples_dask(Client("tcp://192.168.200.104:36091"),_data,
                                               np.tile(np.arange(5,70),100),lognorm,Nterms_base=Nterms)
    print(Nterms,'produced')
    simulations[Nterms]['key'] = 0
    carts = pd.DataFrame({"Nterms used":[1,2,3]})
    carts['key'] = 0
    simulations[Nterms]=simulations[Nterms].set_index('key').join(carts.set_index('key')).reset_index(drop=True)
    def PeriodLimits(df):
        bp = df['_best_period'].iloc[0]
        return pd.Series({"period min":max(np.diff(df.t).min(),0.1*bp), "period max":min(10*bp,df.t.max())})
    simulations[Nterms] =  simulations[Nterms].set_index(["simulation index",'Nterms used'])\
                             .join(simulations[Nterms].groupby(["simulation index",'Nterms used'])\
                             .apply( PeriodLimits)).drop(columns=['_best_period']).reset_index()
    print('limits applied')
    simulations[Nterms].to_csv(folders.ZTF_libraries+f'CEP_dr3_simulations_Nterms_{Nterms}.csv')
# Out:
# 1 produced
# limits applied
# 2 produced
# limits applied
# 3 produced
# limits applied

# %%
def MapWrapper(index,Df):
        df = Df.loc[index].reset_index()
        pars = df.iloc[0]
        model =  gatspy.periodic.LombScargleMultiband(fit_period=True,optimizer_kwds=dict(quiet=True),Nterms_base=pars['Nterms used'])
        model.optimizer.period_range=(pars['period min'],pars['period max'])
        try:
            return index[0],index[1],model.fit(df.t,df.mag,df.magerr,df.filt)._best_period
        except:
            return index[0],index[1],np.nan
sim = simulations[3].set_index(['simulation index','Nterms used'])
ind = pd.unique(sim.index)   
with Client("tcp://192.168.200.104:36091") as client:
    L0 = []
    l = np.arange(0,np.size(ind)+1,600)
    for cut in tqdm.tqdm(range(1,len(l))):
        L0 =L0+ client.gather(client.map(MapWrapper,ind[l[cut-1]:l[cut]],Df=sim.loc[ind[l[cut-1]]:ind[l[cut]-1]]))

L = pd.DataFrame(L0,columns=['simulation index','Nterms used','simulated period'])\
      .set_index(['simulation index','Nterms used'])
simulations[3].drop_duplicates(subset=['simulation index','Nterms used'])\
           .set_index(['simulation index','Nterms used'])\
           .join(L).reset_index().set_index('data index')\
           .join(data).reset_index(drop='True')\
           .to_csv(folders.data_folder+'ZTF/simulations/simulations_summary_output.csv')
# Out:
#   6%|▌         | 498/8905 [8:20:33<161:19:55, 69.08s/it]

# %%
L = pd.DataFrame(L0,columns=['simulation index','Nterms used','simulated period'])\
      .set_index(['simulation index','Nterms used'])
L.to_csv(folders.ZTF_libraries+f'CEP_dr3_simulations_Nterms_{3}_simulated_periods.csv')

# %%
tqdm.notebook.tqdm(desc='Tst')
# Out:
# ...
# Tst: |<bar/>| 0/? [00:00<?, ?it/s]

# %%
def joining(x,L,data):
    return x.reset_index()\
           .drop_duplicates(subset=['simulation index','Nterms used'])\
           .set_index(['simulation index','Nterms used']).join(L)\
           .reset_index().set_index('data index').join(data)\
           .reset_index(drop='True')
sim1=simcodes.MC.Chunk(sim.loc[:ind[l[cut]-1]],600,
                       folders.ZTF_libraries+f'CEP_dr3_simulations_Nterms_{3}_simulated_periods_fold.csv')
sim1.to_csv(folders.ZTF_libraries+f'CEP_dr3_simulations_Nterms_{3}_simulated_periods_joined.csv')
sim1.applyfunc(joining,L,data)
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-55cc95639231> in <module>
#       8                        folders.ZTF_libraries+f'CEP_dr3_simulations_Nterms_{3}_simulated_periods_fold.csv')
#       9 sim1.to_csv(folders.ZTF_libraries+f'CEP_dr3_simulations_Nterms_{3}_simulated_periods_joined.csv')
# ---> 10 sim1.applyfunc(joining,L,data)
#
# TypeError: applyfunc() missing 1 required keyword-only argument: 'desc'

# %%
sim1.to_csv(folders.ZTF_libraries+f'CEP_dr3_simulations_Nterms_{3}_simulated_periods_to_join.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f7b78993670> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f7b78993670> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x7f7b78993670> returned a result with an error set
#
# ...

# %%
import dask.dataframe
dask.dataframe.read_csv(folders.ZTF_libraries+f'CEP_dr3_simulations_Nterms_{3}_simulated_periods.csv')

# %%
sim1.join(L).reset_index().set_index('data index')\
           .join(data).reset_index(drop='True')\
           .to_csv(folders.ZTF_libraries+f'CEP_dr3_simulations_Nterms_{3}_summary_output.csv')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-64-fa831b1e185d> in <module>
# ----> 1 sim1.join(L).reset_index().set_index('data index')\
#       2            .join(data).reset_index(drop='True')\
#       3            .to_csv(folders.ZTF_libraries+f'CEP_dr3_simulations_Nterms_{3}_summary_output.csv')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7206         5  K5  A5  NaN
#    7207         """
# -> 7208         return self._join_compat(
#    7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7222
#    7223         if isinstance(other, DataFrame):
# -> 7224             return merge(
# ...

# %%
d       = pd.read_csv(folders.data_folder+'ZTF/simulations/simulations_summary_output.csv',index_col=0)
d['dP'] = d['simulated period']-d['_best_period']
d['|dP|'] =np.abs( d['simulated period']-d['_best_period'])
d['dP/P'] = d['dP']/d['_best_period']
d['log dP/P'] = np.log10(np.abs(d['dP/P']))
#plt.plot(d.Size,d.dP,'.')
with matplotlib.rc_context({"font.size" : 20,'axes.labelsize':20}):
    fig, ax = plt.subplots(2,2,figsize=(13,10))
    ax=ax.flatten()
    for _, _d in d.dropna().groupby(d.dropna()['Nterms used']):
        if _<3:
            func = [lambda x: np.percentile(x,16),
                           lambda x: np.percentile(x,50),
                           lambda x: np.percentile(x,84),
                          lambda x: scipy.stats.sem(x)]
            vals = {'dP/P':func }

            i = _d.groupby(_d.Size).agg(vals)                                                                               
            i.columns = ['p_16', 'p_50', 'p_84','sem']

            ax[0].plot(i.index,i['p_50'],label=f'{_} LS terms')
            ax[0].set_ylim(-1,1)
            #ax[0].set_yscale('log')
            vals = {'log dP/P':func }
            i = _d.groupby(d.Size).agg(vals)                                                                               
            i.columns = ['p_16', 'p_50', 'p_84','sem']
            ax[1].set_yscale('log')
            ax[1].plot(i.index,10**i['p_50'],label=f'{_} LS terms')
            ax[1].fill_between(i.index,10**i['p_16'],10**i['p_84'],alpha=0.5)
            _d.drop_duplicates(subset=['source_id'])['Subtype'].hist(ax=ax[3])
    dd1=d.groupby(['Nterms used','Size']).count().reset_index()
    dd1['frac'] = 100*dd1['simulated period']/dd1['Subtype']
    for _, _d in dd1.groupby(dd1['Nterms used']):
        ax[2].plot(_d.Size,_d['frac'],label=f'{_} LS terms')
    for a in ax[:3]:
        a.set_xlim(5,70)
        a.legend()
        a.set_xlabel('Simulated observations per band')
    ax[0].set_xlim(5,30)
    ax[0].set_ylabel(r'$\frac{P_{sim}-P_{ZTF}}{P_{ZTF}}$ ')
    ax[1].set_ylabel(r'$\left|\frac{P_{sim}-P_{ZTF}}{P_{ZTF}}\right|$ ')
    ax[2].set_ylabel(r'% of successful fits')
    
    
    fig.tight_layout()
    fig.savefig(folders.plot_folder+f"ztf/simulations.png" , bbox_extra_artists=[fig.suptitle("Median simulated period",y=1.01)],bbox_inches='tight')
    
    for sub,d_ in d.groupby(d.Subtype):
        fig, ax = plt.subplots(1,2,figsize=(13,5))
        for _, _d in d_.dropna().groupby(d_.dropna()['Nterms used']):
            if _<3:
                func = [lambda x: np.percentile(x,16),
                               lambda x: np.percentile(x,50),
                               lambda x: np.percentile(x,84),
                              lambda x: scipy.stats.sem(x)]
                vals = {'dP/P':func }

                i = _d.groupby(_d.Size).agg(vals)                                                                               
                i.columns = ['p_16', 'p_50', 'p_84','sem']

                ax[0].plot(i.index,i['p_50'],label=f'{_} LS terms')
                ax[0].set_ylim(-1,1)
                #ax[0].set_yscale('log')
                vals = {'log dP/P':func }
                i = _d.groupby(_d.Size).agg(vals)                                                                               
                i.columns = ['p_16', 'p_50', 'p_84','sem']
                ax[1].set_yscale('log')
                ax[1].plot(i.index,10**i['p_50'],label=f'{_} LS terms')
                ax[1].fill_between(i.index,10**i['p_16'],10**i['p_84'],alpha=0.5)

        for a in ax:
            a.set_xlim(5,70)
            a.legend()
            a.set_xlabel('Simulated observations per band')
        ax[0].set_ylabel(r'$\frac{P_{sim}-P_{ZTF}}{P_{ZTF}}$ ')
        ax[1].set_ylabel(r'$\left|\frac{P_{sim}-P_{ZTF}}{P_{ZTF}}\right|$ ')
        ax[0].set_xlim(5,30)
        fig.tight_layout()
        fig.savefig(folders.plot_folder+f"ztf/simulations_{sub}.png" , bbox_extra_artists=[fig.suptitle(f"Median simulated period {sub}",y=1.01)],bbox_inches='tight')

# %%
to_join = simulations[3].drop_duplicates(subset=['simulation index','Nterms used'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-d3ac8fee5b10> in <module>
# ----> 1 to_join = simulations[3].drop_duplicates(subset=['simulation index','Nterms used'])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    4809
#    4810         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4811         duplicated = self.duplicated(subset, keep=keep)
#    4812
#    4813         if inplace:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4888         labels, shape = map(list, zip(*map(f, vals)))
#    4889
# -> 4890         ids = get_group_index(labels, shape, sort=False, xnull=False)
#    4891         return Series(duplicated_int64(ids, keep), index=self.index)
#    4892
#
# ...

# %%
for i, _d in concatenated.groupby('Nterms'):
#simulations = simcodes.ExtendedPeriodic.produce_samples(data, np.tile(np.arange(5,100),100),lognorm)
simulations = produce_samples_dask(Client("tcp://192.168.200.104:36091"),data,np.tile(np.arange(5,70),10),lognorm)
print('produced')
simulations['key'] = 0
carts = pd.DataFrame({"Nterms used":[1,2,3]})
carts['key'] = 0
simulations=simulations.set_index('key').join(carts.set_index('key')).reset_index(drop=True)
def PeriodLimits(df):
    bp = df['_best_period'].iloc[0]
    return pd.Series({"period min":max(np.diff(df.t).min(),0.1*bp), "period max":min(10*bp,df.t.max())})
simulations = simulations.set_index(["simulation index",'Nterms used'])\
                         .join(simulations.groupby(["simulation index",'Nterms used'])\
                         .apply( PeriodLimits)).drop(columns=['_best_period']).reset_index()
print('limits applied')
simulations.to_csv(folders.ZTF_libraries+'CEP_dr3_simulations.csv')

with matplotlib.rc_context({"font.size" : 15,'axes.labelsize':15}) as k:
    fig,ax = plt.subplots(1,2,figsize=(10,5))
    
    ax[0].hist(concatenated.magerr,100,density=True,label='dataset',histtype='step')
    ax[0].hist(simulations.magerr,100,density=True,label='simulated',histtype='step')
    ax[0].legend()
    ax[0].set_xlabel('magnitude error');
    ax[1].plot(np.logspace(-4,-2,1000),lognorm.pdf(np.logspace(-4,-2,1000)),'k-',)
    ax[1].set_xscale('log')
    ax[1].set_xlabel('Relative error')
    ax[1].hist(concatenated['magerr']/concatenated.mag,np.logspace(-4,-2,100),density=True,label='dataset',histtype='step')
    ax[1].hist(simulations['magerr']/simulations.mag,np.logspace(-4,-2,100),density=True,label='simulated',histtype='step')
    ax[1].legend()
